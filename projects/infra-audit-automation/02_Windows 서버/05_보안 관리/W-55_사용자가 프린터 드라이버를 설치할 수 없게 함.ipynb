# %%
import sys
from pathlib import Path

# 실행 권장: Jupyter를 `2026 주정통 코드 정리` 폴더에서 실행
# (현재 작업 디렉터리 기준으로 server.py / checks 패키지를 찾을 수 있도록 sys.path를 보정)
for p in [Path.cwd(), *Path.cwd().resolve().parents]:
    if (p / 'server.py').exists():
        sys.path.insert(0, str(p))
        break

from server import Server
from checks.windows import run as run_check

def W_55(server, verbose: bool = True):
    # 작성자 : 자동생성
    # 작성일 : 2026-01-05
    # 점검 항목 : 사용자가 프린터 드라이버를 설치할 수 없게 함 (W-55)
    # 중요도 : 중
    # 점검 영역 : Windows 서버 > 5. 보안 관리

    return run_check('W-55', server, verbose=verbose)

if __name__ == "__main__":
    # 실행 예시(필요시 수정)
    myServer = Server("127.0.0.1", "", "root", "")
    result = W_55(myServer)
    print(result)
